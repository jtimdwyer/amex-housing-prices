# %%
import pandas as pd
import numpy as np
from itertools import product

import seaborn as sns


testcsv = '../../data/kaggle_files/test.csv'
traincsv = '../../data/cleaned/ames_clean.csv'

# %%
df_test = pd.read_csv(testcsv, index_col='Id')
df_train = pd.read_csv(traincsv, index_col='id')
df_test.shape
# Out:
# (879, 79)

# %%
df_test.head()
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 2658  902301120          190        RM          69.0      9142   Pave  Grvl
# 2718  905108090           90        RL           NaN      9662   Pave   NaN
# 2414  528218130           60        RL          58.0     17104   Pave   NaN
# 1989  902207150           30        RM          60.0      8520   Pave   NaN
# 625   535105100           20        RL           NaN      9500   Pave   NaN
#
#      Lot Shape Land Contour Utilities    ...     3Ssn Porch Screen Porch  \
# Id                                       ...
# 2658       Reg          Lvl    AllPub    ...              0            0
# 2718       IR1          Lvl    AllPub    ...              0            0
# 2414       IR1          Lvl    AllPub    ...              0            0
# 1989       Reg          Lvl    AllPub    ...              0            0
# 625        IR1          Lvl    AllPub    ...              0          185
#
#      Pool Area Pool QC Fence Misc Feature Misc Val  Mo Sold  Yr Sold  \
# Id
# 2658         0     NaN   NaN          NaN        0        4     2006
# 2718         0     NaN   NaN          NaN        0        8     2006
# 2414         0     NaN   NaN          NaN        0        9     2006
# 1989         0     NaN   NaN          NaN        0        7     2007
# 625          0     NaN   NaN          NaN        0        7     2009
#
#       Sale Type
# Id
# 2658        WD
# 2718        WD
# 2414        New
# 1989        WD
# 625         WD
#
# [5 rows x 79 columns]

# %%
df_test.columns = df_test.columns.map(lambda col: col.replace(' ','_').lower())
df_test.index.name = 'id'

# %% [markdown]
# Let's drop the PID.

# %%
df_test.drop('pid', axis=1, inplace=True)

# %% [markdown]
# The `ms_subclass` column should be an object, the numbers are just weird codes for various styles of home. This is not a persistent change in the sense that it won't change what happens when the saved CSV is read by pandas, ie I'll have to do this change again when reading the file back into a dataframe, but I'll do it here so I remember to in the future.

# %%
df_test['ms_subclass'] = df_test['ms_subclass'].astype('object').map(str)
df_train['ms_subclass'] = df_train['ms_subclass'].astype('object').map(str)

# %% [markdown]
# Some columns encode the same information. For example there are a number of columns encoding information about the garage. Accoding to the documentation these columns are supposed to be be empty when there is no garage present. So if all of these columns are empty, we'll fill them with a string declaring that that indicates that the garage is missing.
#
# However if some of these columns have values but some do not, for example `Garage Finish` has a value but `Garage Cond` does not, we will drop that row. Some missing entries and some present indicates an error in the row. I'm going to ignore `Garage Yr Blt` for now and handle it at the end since I'm not sure what value it should actually take.

# %% [markdown]
# Fix the `pool_qc`, `misc_feature`, `alley`, `fence`, `fireplace_qe`

# %%
df_test['pool_qc'].fillna(value='No Pool', inplace=True)
df_test['misc_feature'].fillna(value='No Misc Feature', inplace=True)
df_test['alley'].fillna(value='No Alley', inplace=True)
df_test['fence'].fillna(value='No Fence', inplace=True)
df_test['fireplace_qu'].fillna(value='No Fireplace', inplace=True)

# %%
df_test.isnull().sum().sort_values(ascending=False).head()
# Out:
# lot_frontage     160
# garage_yr_blt     45
# garage_finish     45
# garage_qual       45
# garage_cond       45
# dtype: int64

# %%
#keeps rows with no missing info, keeps rows which are missing every entry in the specified columns
#drops all the other rows, fills the missing entries with the new_value

#this is the same as in the training data except we're no longer dropping rows with contadictory data in these columns
#so now we're just filling the rows with all nan in garage/basement

def frame_column_filler(df, columns, new_value, inplace=False):
    if not inplace:
        tmp_df = df.copy()
    else:
        tmp_df = df
    
    num_nan = tmp_df[columns].isnull().sum(1)
    
    all_nan = set(num_nan[num_nan.apply(lambda x: x == len(columns))].index)
    no_nan = set(num_nan[num_nan.apply(lambda x: x == 0)].index)
    some_missing = {x for x in tmp_df.index if x not in all_nan.union(no_nan)}
    
    
    for index in tmp_df.index:
        if index in all_nan:
            for col in columns:
                tmp_df.at[index, col] = new_value
        
    if not inplace:
        return tmp_df

# %%
garage_cols = ['garage_cond', 'garage_qual', 'garage_finish', 'garage_type']
frame_column_filler(df_test, garage_cols, 'No Garage', inplace=True)

# %%
df_test.isnull().sum().sort_values(ascending=False).head()
# Out:
# lot_frontage      160
# garage_yr_blt      45
# bsmtfin_type_2     25
# bsmtfin_type_1     25
# bsmt_exposure      25
# dtype: int64

# %% [markdown]
# I'm going to drop the `Garage Yr Blt` now and see how well we can do without it. I would think that newer garages would maybe be menaingful, but I'm not sure how to encode this column for those houses without a garage.

# %%
df_test.drop('garage_yr_blt', axis=1, inplace=True)

# %%
basement_cols = ['bsmt_exposure', 'bsmtfin_type_2', 'bsmt_cond', 'bsmt_qual','bsmtfin_type_1']
frame_column_filler(df_test, basement_cols, 'No Basement', inplace=True)

# %%
df_test.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# lot_frontage     160
# mas_vnr_area       1
# garage_finish      1
# electrical         1
# garage_qual        1
# garage_cond        1
# mas_vnr_type       1
# sale_type          0
# roof_style         0
# roof_matl          0
# dtype: int64

# %% [markdown]
# The final rows that I believe are true errors in the missing values are the ones below `Lot Frontage`. We'll drop those rows now, then impute values for `Lot Frontage` based on `MS SubClass`.

# %%
df_train
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street     alley lot_shape  \
# id
# 109           60        RL          75.0     13517   Pave  No Alley       IR1
# 544           60        RL          43.0     11492   Pave  No Alley       IR1
# 153           20        RL          68.0      7922   Pave  No Alley       Reg
# 318           60        RL          73.0      9802   Pave  No Alley       Reg
# 255           50        RL          82.0     14235   Pave  No Alley       IR1
# 138           20        RL         137.0     16492   Pave  No Alley       IR1
# 2827         180        RM          35.0      3675   Pave  No Alley       Reg
# 145           20        RL          75.0     12160   Pave  No Alley       IR1
# 1942          20        RL          75.0     15783   Pave  No Alley       Reg
# 1956          60        RL          70.0     11606   Pave  No Alley       IR1
# 1044         160        RM          21.0      1680   Pave  No Alley       Reg
# 2752          20        RL          64.0      7488   Pave  No Alley       IR1
# 807           70        RL         120.0     26400   Pave  No Alley       Reg
# 1177         160        FV          24.0      2645   Pave      Pave       Reg
# 1480          20        RL          74.0      9627   Pave  No Alley       Reg
# 324           20        RL          93.0     10114   Pave  No Alley       Reg
# 1311          70        RM          34.0      4571   Pave      Grvl       Reg
# 770           20        RL          80.0      8816   Pave  No Alley       Reg
# 2063          20        RL          71.0      8197   Pave  No Alley       Reg
# 69            60        FV          72.0      8640   Pave  No Alley       Reg
# 2062          20        RL         109.0      8724   Pave  No Alley       Reg
# 351          120        RL          40.0      5664   Pave  No Alley       IR1
# 12            20        RL          75.0      7980   Pave  No Alley       IR1
# 2339         190        RL         100.0     34650   Pave  No Alley       Reg
# 624           20        RL          92.0     10573   Pave  No Alley       IR1
# 86            20        RL          65.0      8450   Pave  No Alley       Reg
# 1534          50        RL          60.0     11700   Pave      Grvl       IR1
# 2243         190   C (all)          75.0      8250   Pave  No Alley       Reg
# 1957          50        RL          60.0      8064   Pave  No Alley       Reg
# 380           20        RL          80.0      9600   Pave  No Alley       Reg
# ...          ...       ...           ...       ...    ...       ...       ...
# 2810          60        RL          70.0      8400   Pave  No Alley       Reg
# 2872          20        RL          75.0     16381   Pave  No Alley       IR1
# 1072         120        RL         135.0     12304   Pave  No Alley       IR3
# 1654          60        RL          80.0     11584   Pave  No Alley       Reg
# 2394          60        RL          82.0     10672   Pave  No Alley       IR1
# 2212          70        RL          60.0      7230   Pave  No Alley       Reg
# 2628          90        RL          75.0      8512   Pave  No Alley       Reg
# 2526          20        RL          75.0     20781   Pave  No Alley       IR2
# 969           20        RL          85.0     12633   Pave  No Alley       IR1
# 306           50   C (all)          66.0      8712   Pave      Pave       Reg
# 25            20        RL          75.0     12537   Pave  No Alley       IR1
# 311           80        RL          74.0      9620   Pave  No Alley       Reg
# 300          120        RM          35.0      3907   Pave  No Alley       IR1
# 2775          20        RL          79.0      9236   Pave  No Alley       IR1
# 2862          30        RL          80.0     11600   Pave  No Alley       Reg
# 525           60        FV          84.0     10603   Pave  No Alley       Reg
# 2730          20        RL         100.0     13350   Pave  No Alley       IR1
# 1892          80        RL          80.0      9200   Pave  No Alley       Reg
# 2288         160        RM          21.0      1495   Pave  No Alley       Reg
# 2728          50        RL          81.0     15593   Pave  No Alley       Reg
# 1065          60        RL         110.0     13688   Pave  No Alley       IR1
# 2842          50        RL          45.0      8248   Pave      Grvl       Reg
# 2011          70        RM          50.0      6000   Pave  No Alley       Reg
# 1140          60        RL          65.0      8453   Pave  No Alley       IR1
# 1051          20        RL          96.0     12444   Pave  No Alley       Reg
# 1587          20        RL          79.0     11449   Pave  No Alley       IR1
# 785           30        RL          60.0     12342   Pave  No Alley       IR1
# 916           50        RL          57.0      7558   Pave  No Alley       Reg
# 639           20        RL          80.0     10400   Pave  No Alley       Reg
# 10            60        RL          60.0      7500   Pave  No Alley       Reg
#
#      land_contour utilities lot_config    ...     screen_porch pool_area  \
# id                                        ...
# 109           Lvl    AllPub    CulDSac    ...                0         0
# 544           Lvl    AllPub    CulDSac    ...                0         0
# 153           Lvl    AllPub     Inside    ...                0         0
# 318           Lvl    AllPub     Inside    ...                0         0
# 255           Lvl    AllPub     Inside    ...                0         0
# 138           Lvl    AllPub     Corner    ...                0         0
# 2827          Lvl    AllPub     Inside    ...                0         0
# 145           Lvl    AllPub     Inside    ...                0         0
# 1942          Lvl    AllPub     Inside    ...                0         0
# 1956          HLS    AllPub     Inside    ...                0         0
# 1044          Lvl    AllPub     Inside    ...                0         0
# 2752          Lvl    AllPub     Inside    ...                0         0
# 807           Bnk    AllPub        FR2    ...                0         0
# 1177          Lvl    AllPub     Inside    ...                0         0
# 1480          Lvl    AllPub     Inside    ...                0         0
# 324           Lvl    AllPub     Inside    ...                0         0
# 1311          Lvl    AllPub     Inside    ...                0         0
# 770           Lvl    AllPub     Corner    ...                0         0
# 2063          Lvl    AllPub     Inside    ...                0         0
# 69            Lvl    AllPub     Inside    ...                0         0
# 2062          Lvl    AllPub     Inside    ...                0         0
# 351           Lvl    AllPub     Inside    ...                0         0
# 12            Lvl    AllPub     Inside    ...                0         0
# 2339          Bnk    AllPub     Inside    ...                0         0
# 624           Lvl    AllPub     Corner    ...              288         0
# 86            Lvl    AllPub     Inside    ...                0         0
# 1534          HLS    AllPub     Inside    ...                0         0
# 2243          Lvl    AllPub     Inside    ...                0         0
# 1957          Lvl    AllPub     Corner    ...                0         0
# 380           Lvl    AllPub     Inside    ...                0         0
# ...           ...       ...        ...    ...              ...       ...
# 2810          Lvl    AllPub     Inside    ...                0         0
# 2872          Lvl    AllPub     Inside    ...                0         0
# 1072          Lvl    AllPub     Corner    ...                0         0
# 1654          Lvl    AllPub     Inside    ...                0         0
# 2394          Lvl    AllPub     Inside    ...                0         0
# 2212          Lvl    AllPub     Inside    ...              153         0
# 2628          Lvl    AllPub     Corner    ...                0         0
# 2526          Lvl    AllPub    CulDSac    ...                0         0
# 969           HLS    AllPub     Inside    ...                0         0
# 306           HLS    AllPub     Inside    ...                0         0
# 25            Lvl    AllPub    CulDSac    ...                0         0
# 311           Lvl    AllPub     Inside    ...                0         0
# 300           HLS    AllPub     Inside    ...                0         0
# 2775          Lvl    AllPub     Inside    ...                0         0
# 2862          Lvl    AllPub     Inside    ...                0         0
# 525           Lvl    AllPub     Inside    ...                0         0
# 2730          Lvl    AllPub     Inside    ...                0         0
# 1892          Lvl    AllPub     Inside    ...                0         0
# 2288          Lvl    AllPub     Inside    ...                0         0
# 2728          Lvl    AllPub     Corner    ...                0         0
# 1065          Lvl    AllPub     Inside    ...                0         0
# 2842          Lvl    AllPub     Inside    ...                0         0
# 2011          Lvl    AllPub     Inside    ...                0         0
# 1140          Lvl    AllPub     Inside    ...                0         0
# 1051          Lvl    AllPub        FR2    ...                0         0
# 1587          HLS    AllPub     Inside    ...                0         0
# 785           Lvl    AllPub     Inside    ...                0         0
# 916           Bnk    AllPub     Inside    ...                0         0
# 639           Lvl    AllPub     Corner    ...                0         0
# 10            Lvl    AllPub     Inside    ...                0         0
#
#       pool_qc     fence     misc_feature misc_val  mo_sold  yr_sold  \
# id
# 109   No Pool  No Fence  No Misc Feature        0        3     2010
# 544   No Pool  No Fence  No Misc Feature        0        4     2009
# 153   No Pool  No Fence  No Misc Feature        0        1     2010
# 318   No Pool  No Fence  No Misc Feature        0        4     2010
# 255   No Pool  No Fence  No Misc Feature        0        3     2010
# 138   No Pool  No Fence  No Misc Feature        0        6     2010
# 2827  No Pool  No Fence  No Misc Feature        0        6     2006
# 145   No Pool     MnPrv  No Misc Feature        0        5     2010
# 1942  No Pool     MnPrv             Shed      400        6     2007
# 1956  No Pool  No Fence  No Misc Feature        0        9     2007
# 1044  No Pool  No Fence  No Misc Feature        0        7     2008
# 2752  No Pool  No Fence  No Misc Feature        0        2     2006
# 807   No Pool  No Fence  No Misc Feature        0        6     2009
# 1177  No Pool  No Fence  No Misc Feature        0       12     2008
# 1480  No Pool  No Fence  No Misc Feature        0        6     2008
# 324   No Pool  No Fence  No Misc Feature        0        3     2010
# 1311  No Pool  No Fence  No Misc Feature        0        5     2008
# 770   No Pool     MnPrv  No Misc Feature        0        6     2009
# 2063  No Pool     MnPrv  No Misc Feature        0        4     2007
# 69    No Pool  No Fence  No Misc Feature        0        6     2010
# 2062  No Pool  No Fence  No Misc Feature        0        5     2007
# 351   No Pool  No Fence  No Misc Feature        0       10     2009
# 12    No Pool     GdPrv             Shed      500        3     2010
# 2339  No Pool  No Fence  No Misc Feature        0        1     2006
# 624   No Pool     GdPrv  No Misc Feature        0        4     2009
# 86    No Pool     MnPrv  No Misc Feature        0        4     2010
# 1534  No Pool  No Fence  No Misc Feature        0        7     2008
# 2243  No Pool  No Fence  No Misc Feature        0        6     2007
# 1957  No Pool     MnPrv             Shed     2000        7     2007
# 380   No Pool     MnPrv  No Misc Feature        0        7     2009
# ...       ...       ...              ...      ...      ...      ...
# 2810  No Pool  No Fence  No Misc Feature        0        3     2006
# 2872  No Pool  No Fence  No Misc Feature        0       12     2006
# 1072  No Pool  No Fence  No Misc Feature        0        6     2008
# 1654  No Pool  No Fence  No Misc Feature        0       11     2007
# 2394  No Pool  No Fence  No Misc Feature        0       11     2006
# 2212  No Pool     GdPrv  No Misc Feature        0       10     2007
# 2628  No Pool  No Fence  No Misc Feature        0        9     2006
# 2526  No Pool  No Fence  No Misc Feature        0        6     2006
# 969   No Pool  No Fence  No Misc Feature        0        5     2009
# 306   No Pool  No Fence  No Misc Feature        0        1     2010
# 25    No Pool  No Fence  No Misc Feature        0        4     2010
# 311   No Pool     GdPrv             Shed       80        5     2010
# 300   No Pool  No Fence  No Misc Feature        0        3     2010
# 2775  No Pool  No Fence  No Misc Feature        0        7     2006
# 2862  No Pool  No Fence  No Misc Feature        0        7     2006
# 525   No Pool  No Fence  No Misc Feature        0        7     2009
# 2730  No Pool     MnPrv  No Misc Feature        0        6     2006
# 1892  No Pool     GdPrv  No Misc Feature        0        5     2007
# 2288  No Pool  No Fence  No Misc Feature        0        5     2007
# 2728  No Pool  No Fence  No Misc Feature        0        7     2006
# 1065  No Pool  No Fence  No Misc Feature        0        3     2008
# 2842  No Pool  No Fence  No Misc Feature        0        9     2006
# 2011  No Pool      GdWo  No Misc Feature        0        2     2007
# 1140  No Pool  No Fence  No Misc Feature        0        4     2008
# 1051  No Pool  No Fence  No Misc Feature        0       11     2008
# 1587  No Pool  No Fence  No Misc Feature        0        1     2008
# 785   No Pool  No Fence  No Misc Feature        0        3     2009
# 916   No Pool  No Fence  No Misc Feature        0        3     2009
# 639   No Pool  No Fence  No Misc Feature        0       11     2009
# 10    No Pool  No Fence  No Misc Feature        0        6     2010
#
#       sale_type  saleprice
# id
# 109         WD      130500
# 544         WD      220000
# 153         WD      109000
# 318         WD      174000
# 255         WD      138500
# 138         WD      190000
# 2827        New     140000
# 145         COD     142000
# 1942        WD      112500
# 1956        WD      135000
# 1044        COD      85400
# 2752        WD      183600
# 807         WD      131000
# 1177      ConLD     200000
# 1480        WD      193000
# 324         WD      173500
# 1311        COD      98000
# 770         WD      139000
# 2063        WD      143500
# 69          Con     215200
# 2062        WD      129000
# 351         WD      278000
# 12          WD      185000
# 2339        WD      145000
# 624         WD      187500
# 86          WD      138500
# 1534        WD      198000
# 2243        WD      119600
# 1957        WD      122900
# 380         WD      278000
# ...         ...        ...
# 2810        WD      195800
# 2872        WD      223000
# 1072        WD      192000
# 1654        WD      197000
# 2394        New     298236
# 2212        WD      238000
# 2628        WD      119000
# 2526        WD      262500
# 969         WD      425000
# 306         WD      102776
# 25          WD      149900
# 311         WD      190000
# 300         WD      162500
# 2775        WD      217000
# 2862        WD      137500
# 525         WD      270000
# 2730        WD      142500
# 1892        WD      161000
# 2288        WD       93900
# 2728        WD      225000
# 1065        WD      412500
# 2842        COD      83000
# 2011        WD      128000
# 1140        WD      182000
# 1051        New     394617
# 1587        WD      298751
# 785         WD       82500
# 916         WD      177000
# 639         WD      144000
# 10          WD      189000
#
# [2016 rows x 78 columns]

# %%
medians = df_train[['lot_frontage', 'ms_subclass']].groupby('ms_subclass').agg(np.median).copy()
medians = {x:y[0] for x,y in zip(medians.index, medians.values)}

# %%
medians
# Out:
# {'120': 43.0,
#  '160': 24.0,
#  '180': 21.0,
#  '190': 65.0,
#  '20': 75.0,
#  '30': 60.0,
#  '40': 52.5,
#  '45': 51.0,
#  '50': 60.0,
#  '60': 75.0,
#  '70': 60.0,
#  '75': 65.0,
#  '80': 78.0,
#  '85': 70.0,
#  '90': 70.0}

# %%
for index, lf, ms_sub in df_test[['lot_frontage', 'ms_subclass']].to_records():
    if np.isnan(lf):
#         print(ms_sub)
        df_test.at[index, 'lot_frontage'] = medians[ms_sub]

# %%
df_test.isnull().sum().sum(), df_test.shape
# Out:
# (6, (879, 77))

# %%
df_test.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# mas_vnr_area     1
# garage_finish    1
# electrical       1
# garage_qual      1
# garage_cond      1
# mas_vnr_type     1
# sale_type        0
# roof_style       0
# roof_matl        0
# exterior_1st     0
# dtype: int64

# %% [markdown]
# Let's find the rows that need to be fixed still.

# %%
df_test[df_test.isnull().sum(1).astype('bool')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street     alley lot_shape  \
# id
# 1578          80        RL          73.0      9735   Pave  No Alley       Reg
# 1357          60        RM          57.0      8094   Pave      Grvl       Reg
# 868           60        RL          70.0      8749   Pave  No Alley       Reg
#
#      land_contour utilities lot_config    ...     3ssn_porch screen_porch  \
# id                                        ...
# 1578          Lvl    AllPub     Inside    ...              0            0
# 1357          Lvl    AllPub     Inside    ...              0            0
# 868           Lvl    AllPub     Inside    ...              0            0
#
#      pool_area  pool_qc     fence     misc_feature  misc_val  mo_sold  \
# id
# 1578         0  No Pool  No Fence  No Misc Feature         0        5
# 1357         0  No Pool     MnPrv             Shed      1000        9
# 868          0  No Pool  No Fence  No Misc Feature         0       11
#
#       yr_sold  sale_type
# id
# 1578     2008        WD
# 1357     2008        WD
# 868      2009        WD
#
# [3 rows x 77 columns]

# %%
df_test.loc[1578].isnull().sum()
# Out:
# 1

# %%
df_test.at[1578, 'electrical']
# Out:
# nan

# %%
df_train.electrical.value_counts()
# Out:
# SBrkr    1835
# FuseA     138
# FuseF      35
# FuseP       7
# Mix         1
# Name: electrical, dtype: int64

# %%
df_test.at[1578, 'electrical'] = 'SBrkr'

# %%
df_test.loc[868].isnull().sum()
# Out:
# 2

# %%
df_test.loc[868]['mas_vnr_area']
# Out:
# nan

# %%
df_test.loc[868]['mas_vnr_type']
# Out:
# nan

# %%
df_train['mas_vnr_area'].value_counts().head()
# Out:
# 0.0      1211
# 120.0      11
# 200.0      10
# 176.0      10
# 72.0        9
# Name: mas_vnr_area, dtype: int64

# %%
df_train['mas_vnr_type'].value_counts().head()
# Out:
# None       1208
# BrkFace     627
# Stone       168
# BrkCmn       13
# Name: mas_vnr_type, dtype: int64

# %%
df_test.at[868,'mas_vnr_area'] = 0
df_test.at[868,'mas_vnr_type'] = 'None'

# %%
df_test.loc[1357].isnull().sum()
# Out:
# 3

# %%
for col in df_test.columns:
    if 'garage' in col:
        print(col, df_test.at[1357,col])
# Out:
# garage_type Detchd
# garage_finish nan
# garage_cars 1.0
# garage_area 360.0
# garage_qual nan
# garage_cond nan

# %%
df_train[(df_train['garage_type']=='Detchd') & (df_train['garage_cars'] == 1)]['garage_finish'].value_counts()
# Out:
# Unf    243
# RFn      5
# Fin      2
# Name: garage_finish, dtype: int64

# %%
df_train[(df_train['garage_type']=='Detchd') & (df_train['garage_cars'] == 1)]['garage_qual'].value_counts()
# Out:
# TA    201
# Fa     44
# Po      2
# Ex      2
# Gd      1
# Name: garage_qual, dtype: int64

# %%
df_train[(df_train['garage_type']=='Detchd') & (df_train['garage_cars'] == 1)]['garage_cond'].value_counts()
# Out:
# TA    217
# Fa     27
# Po      4
# Ex      2
# Name: garage_cond, dtype: int64

# %%
for col in df_test.columns:
    if 'garage' in col:
        if pd.isnull(df_test.at[1357,col]):
            print(col, df_test.at[1357,col])
# Out:
# garage_finish nan
# garage_qual nan
# garage_cond nan

# %%
for col in df_test.columns:
    if 'garage' in col:
        if pd.isnull(df_test.at[1357,col]):
            print(col, df_test.at[1357,col])
            df_test.at[1357,col] = df_train[(df_train['garage_type']=='Detchd') & \
                                 (df_train['garage_cars'] == 1)][col].value_counts().index[0]
            print(col, df_test.at[1357,col])
# Out:
# garage_finish nan
# garage_finish Unf
# garage_qual nan
# garage_qual TA
# garage_cond nan
# garage_cond TA

# %%
df_test.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# No more null data at least, maybe I made bad choices about imputing, we shall see.

# %%
df_test.to_csv('../../data/cleaned/ames_clean_test.csv')

# %% [markdown]
# There could still be lots of outliers or other just wrong data that needs to be removed. Hopefully this will be discovered in EDA.
